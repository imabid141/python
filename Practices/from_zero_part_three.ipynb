# %% [markdown]
# ### 1️⃣ What Is a Function?
#
# A **function** is a block of code that performs a specific task and can be reused.
#
# Instead of writing the same code many times, we **put it inside a function**.
#
# #### Example (without function)

# %%
# Repatitive code

print(5 * 5)
print(6 * 6)
print(7 * 7)
# Out:
# 25
# 36
# 49

# %%
# Example (with function)

def square(x):
    return x * x

print(square(5))
print(square(6))
print(square(7))
# Out:
# 25
# 36
# 49

# %% [markdown]
# ### 3️⃣ Key Parts of a Function
#
# #### 1️⃣ `def`
#
# Tells Python **we are creating a function**.
#
# ```
# def greet():
# ```
#
# #### 2️⃣ Function Name
#
# ```
# greet
# add
# square
# clean_data
# ```
#
# Choose meaningful names.
#
# #### 3️⃣ Parameters
#
# These are **inputs** to the function.
#
# ```python
# def add(a, b):
# ```
#
# Here:
#
# ```
# a
# b
# ```
#
# are parameters.
#
# #### 4️⃣ `return`
#
# `return` sends the result back.
#
# ```python
# return a + b
# ```
#
# Without `return`, the function gives **None**.

# %% [markdown]
# #### 5️⃣ Very Important Difference

# %%
# Function with return

def multiply(a, b):
    return a * b

result = multiply(3, 4)
print(result)
# Out:
# 12

# %%
# Function without return

def multiply(a, b):
    print(a * b)

result = multiply(3, 4)
print(result)
# Out:
# 12
# None

# %% [markdown]
# Output:
#
# ```
# 12
# None
# ```
#
# Because the function **did not return anything**.

# %% [markdown]
# ### Small Exercise For You
#
# Tell me the **output and explanation**.
#
# #### Question 1
#
# ```python
# def add(a, b):
#     return a + b
#
# print(add(2, 3))
# ```
#
# Options:
#
# A) 5
# B) 23
# C) None
# D) Error
#
# Explain **why**.
#
# #### Question 2
#
# ```python
# def greet(name):
#     print("Hello", name)
#
# x = greet("Abid")
# print(x)
# ```
#
# What is the **output**?
#
# Explain step by step.

# %%
# Question 1
def add(a, b):
    return a + b

print(add(2, 3))
# Out:
# 5

# %%
# Question 2
def greet(name):
    print("Hello", name)

x = greet("Abid")
print(x)
# Out:
# Hello Abid
# None

# %% [markdown]
# ### Review of Small Exercise
#
# Good work, **Abid**. You’re understanding the **core idea of functions**, which is very important. Let’s finish reviewing your answers carefully.
#
# #### 1️⃣ Question 1
#
# ```python
# def add(a, b):
#     return a + b
#
# print(add(2, 3))
# ```
#
# Your answer: **A) 5**
#
# ✅ **Correct**
#
# Explanation step-by-step:
#
# 1. Function `add` takes two parameters: `a` and `b`.
# 2. When we call:
#
# ```python
# add(2, 3)
# ```
#
# 3. Python assigns:
#
# ```
# a = 2
# b = 3
# ```
#
# 4. The function returns:
#
# ```
# 2 + 3 = 5
# ```
#
# 5. `print()` prints the result.
#
# Output:
#
# ```
# 5
# ```
#
# #### 2️⃣ Question 2
#
# ```python
# def greet(name):
#     print("Hello", name)
#
# x = greet("Abid")
# print(x)
# ```
#
# You said the output is:
#
# ```
# Hello Abid
# None
# ```
#
# ✅ **Correct again**
#
# Step-by-step:
#
# 1️⃣ Function runs:
#
# ```
# print("Hello", "Abid")
# ```
#
# Output:
#
# ```
# Hello Abid
# ```
#
# 2️⃣ But the function **does not return anything**.
#
# So Python automatically returns:
#
# ```
# None
# ```
#
# 3️⃣ Therefore:
#
# ```
# x = None
# ```
#
# 4️⃣ When we print `x`:
#
# ```
# print(x)
# ```
#
# Output:
#
# ```
# None
# ```
#
# Final output:
#
# ```
# Hello Abid
# None
# ```

# %% [markdown]
# ### Now Let's Learn Something Very Important
#
# #### Functions With Default Values
#
# Example:
#
# ```python
# def greet(name="User"):
#     print("Hello", name)
#
# greet()
# greet("Abid")
# ```
#
# Output:
#
# ```
# Hello User
# Hello Abid
# ```
#
# If no argument is given, the **default value** is used.

# %%
def greet(name="User"):
    print("Hello", name)

greet()
greet("Abid")
# Out:
# Hello User
# Hello Abid

# %% [markdown]
# ### Small Exercises For You
#
# Try to think carefully.
#
# #### Question 1
#
# ```python
# def multiply(a, b=2):
#     return a * b
#
# print(multiply(5))
# ```
#
# Options:
#
# A) 10
# B) 5
# C) Error
# D) None
#
# Explain **why**.

# %%
# Question 1

def multiply(a, b=2):
    return a * b

print(multiply(5))
# Out:
# 10

# %% [markdown]
# #### Question 2
#
# ```python
# def add(a, b):
#     print(a + b)
#
# x = add(4,5)
# print(x)
# ```
#
# What is the output?

# %%
# Question 2

def add(a, b):
    print(a + b)

x = add(4,5)
print(x)
# Out:
# 9
# None

# %% [markdown]
# #### Question 3 (Important Thinking)
#
# ```python
# def test(x):
#     x = x + 5
#     return x
#
# a = 10
# test(a)
#
# print(a)
# ```
#
# Options:
#
# A) 15
# B) 10
# C) None
# D) Error
#
# Answer them slowly and explain like before.

# %%
# Question 3

def test(x):
    x = x + 5
    return x

a = 10
test(a)

print(a)
# Out:
# 10

# %% [markdown]
# ### Review for exercises
# Excellent work, **Abid**. 👍
# Your reasoning is becoming **clear and structured**, which is exactly how good programmers think. Let’s review each answer like a teacher.
#
# #### 1️⃣ Question 1 Review
#
# ```python
# def multiply(a, b=2):
#     return a * b
#
# print(multiply(5))
# ```
#
# Your answer: **A) 10**
#
# ✅ **Correct**
#
# Your explanation is also correct.
#
# Step-by-step:
#
# 1. Function definition:
#
# ```
# a → required parameter
# b → default parameter = 2
# ```
#
# 2. Function call:
#
# ```python
# multiply(5)
# ```
#
# Python assigns:
#
# ```
# a = 5
# b = 2 (default value)
# ```
#
# 3. Calculation:
#
# ```
# 5 * 2 = 10
# ```
#
# Output:
#
# ```
# 10
# ```
#
# Very good explanation from you.
#
# #### 2️⃣ Question 2 Review
#
# ```python
# def add(a, b):
#     print(a + b)
#
# x = add(4,5)
# print(x)
# ```
#
# Your answer:
#
# ```
# 9
# None
# ```
#
# ✅ **Correct**
#
# Step-by-step:
#
# 1️⃣ Function runs:
#
# ```
# print(4 + 5)
# ```
#
# Output:
#
# ```
# 9
# ```
#
# 2️⃣ Function has **no return statement**, so Python returns:
#
# ```
# None
# ```
#
# 3️⃣ So:
#
# ```
# x = None
# ```
#
# 4️⃣ When we print `x`:
#
# ```
# print(x)
# ```
#
# Output:
#
# ```
# None
# ```
#
# Final output:
#
# ```
# 9
# None
# ```
#
# Your reasoning here was **perfect**.
#
# #### 3️⃣ Question 3 Review
#
# ```python
# def test(x):
#     x = x + 5
#     return x
#
# a = 10
# test(a)
#
# print(a)
# ```
#
# Your answer: **B) 10**
#
# ✅ **Correct again**
#
# Your explanation is also right.
#
# Step-by-step:
#
# 1️⃣ `a = 10`
#
# 2️⃣ Function call:
#
# ```
# test(a)
# ```
#
# Inside the function:
#
# ```
# x = 10
# x = x + 5
# x = 15
# return 15
# ```
#
# But the returned value is **not stored anywhere**.
#
# We did NOT write:
#
# ```
# a = test(a)
# ```
#
# So the original variable **`a` remains unchanged**.
#
# Therefore:
#
# ```
# print(a)
# ```
#
# Output:
#
# ```
# 10
# ```

# %% [markdown]
# ### ⭐ Very Important Concept (Function Scope)
#
# This is where many beginners get confused.
#
# #### Example 1
#
# ```python
# def change(x):
#     x = 20
#
# a = 10
# change(a)
#
# print(a)
# ```
#
# Output:
#
# ```
# 10
# ```
#
# Because the function works on a **copy of the value**.
#
# #### Example 2 (value updated)
#
# ```python
# def change(x):
#     x = 20
#     return x
#
# a = 10
# a = change(a)
#
# print(a)
# ```
#
# Output:
#
# ```
# 20
# ```
#
# Because we **saved the returned value**.

# %% [markdown]
# ### 🔥 Now Let's Do a Real Programming Exercise
#
# This is closer to **real Python work**.
#
# #### Problem
#
# Create a function that **converts dollars to rupees**.
#
# Example:
#
# ```
# 1 USD = 280 PKR
# ```
#
# #### Function:
#
# ```python
# def usd_to_pkr(usd):
#     # your code
# ```
#
# Example usage:
#
# ```python
# print(usd_to_pkr(10))
# ```
#
# Expected output:
#
# ```
# 2800
# ```
#
# #### 🧠 Second Exercise (Very Important)
#
# Predict the output.
#
# ```python
# def add(a, b):
#     return a + b
#
# x = add(2,3)
# y = add(x,4)
#
# print(y)
# ```
#
# Options:
#
# A) 5
# B) 9
# C) 7
# D) Error
#
# Explain **step by step like before**.

# %%
# Function

def usd_to_pkr(a, b=280):
    return a * b

print(usd_to_pkr(10))
# Out:
# 2800

# %%
# Exercise

def add(a, b):
    return a + b

x = add(2,3)
y = add(x,4)

print(y)
# Out:
# 9

# %% [markdown]
# ### Review
# Excellent, **Abid**. You’re doing very well with functions. Your logic is mostly correct. Let’s review both parts carefully like a mentor reviewing your code. 👍
#
# #### 1️⃣ Your Function: USD → PKR
#
# Your code:
#
# ```python
# def usd_to_pkr(a, b=280):
#     return a * b
#
# print(usd_to_pkr(10))
# ```
#
# Output:
#
# ```
# 2800
# ```
#
# ✅ **Correct**
#
# Explanation:
#
# * `a = 10`
# * `b = 280` (default value)
#
# Calculation:
#
# ```
# 10 * 280 = 2800
# ```
#
# So the function returns **2800**.
#
# #### Small improvement (professional naming)
#
# Good programmers use **clear variable names**.
#
# Better version:
#
# ```python
# def usd_to_pkr(usd, rate=280):
#     return usd * rate
#
# print(usd_to_pkr(10))
# ```
#
# This makes the code easier to understand.
#
# ---
#
# #### 2️⃣ Second Exercise
#
# Code:
#
# ```python
# def add(a, b):
#     return a + b
#
# x = add(2,3)
# y = add(x,4)
#
# print(y)
# ```
#
# Your answer: **B) 9**
#
# ✅ **Correct**
#
# Your reasoning was good, but there was **one small typing mistake** in the explanation.
#
# You wrote:
#
# > 5 + 9 = 9
#
# But the correct calculation is:
#
# ```
# 5 + 4 = 9
# ```
#
# Let’s solve step-by-step.
#
# #### Step 1
#
# ```
# x = add(2,3)
# ```
#
# Inside the function:
#
# ```
# 2 + 3 = 5
# ```
#
# So:
#
# ```
# x = 5
# ```
#
# #### Step 2
#
# ```
# y = add(x,4)
# ```
#
# Since `x = 5`:
#
# ```
# add(5,4)
# ```
#
# Inside the function:
#
# ```
# 5 + 4 = 9
# ```
#
# So:
#
# ```
# y = 9
# ```
#
# #### Step 3
#
# ```
# print(y)
# ```
#
# Output:
#
# ```
# 9
# ```
