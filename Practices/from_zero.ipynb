# %% [markdown]
# ### This Notbook is my personal learning with ChatGPT

# %% [markdown]
# #### Exercise 1
#
# Create variables for:
#
# * Your name
# * Your age
# * Your favorite number
#
# Then print them.

# %%
# Exercise 1
name = "M Abid"
age = 25
fav_num = 27

print(name)
print(age)
print(fav_num)
# Out:
# M Abid
# 25
# 27

# %% [markdown]
# Excellent work, Abid! 👏🔥
#
# You did everything correctly.
#
# #### Exercise 1 Review
#
# ```python
# name = "M Abid"
# age = 25
# fav_number = 27
#
# print(name)
# print(age)
# print(fav_number)
# ```
#
# ✔ Variables created correctly
# ✔ Correct data types (string + integers)
# ✔ Correct printing
#
# Very good start
